# %%
import numpy as np
import pandas as pd

data = pd.read_csv('data.csv')
data = data.set_index('date')# 将date设置为index

# %%
data.head()
# Out:
#                0:00:00     1:00:00     2:00:00     3:00:00     4:00:00  \
# date
# 2018-01-01  498.849711  568.722783  571.976601  565.685116  557.767855
# 2018-01-02  138.682982  138.687231  138.587451  137.097339  147.389217
# 2018-01-03  276.029268  392.131019  227.464215  183.000956  179.681595
# 2018-01-04  367.463649  409.269834  286.109966  255.044034  247.185864
# 2018-01-05  232.290388  220.279973  161.365365  136.924702  134.806185
#
#                5:00:00     6:00:00     7:00:00     8:00:00     9:00:00  \
# date
# 2018-01-01  538.997216  503.920159  501.880084  409.504079  348.658712
# 2018-01-02  171.469343  181.241544  190.673310  188.913216  144.557751
# 2018-01-03  259.146483  313.583010  280.530973  272.014769  283.858254
# 2018-01-04  276.671340  231.293024  195.366763  156.425822  173.028752
# 2018-01-05  133.233337  128.350867  122.988473  121.982310  106.687148
#
#                ...        14:00:00    15:00:00    16:00:00    17:00:00  \
# date           ...
# ...
